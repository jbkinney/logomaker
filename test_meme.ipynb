# %%
from __future__ import division
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl
import re

# Import LogoMaker
import logomaker

# %matplotlib inline
plt.ion()

# %%
logo= logomaker.make_logo(meme_file='data/17_vakoc/molm13_2.txt', meme_motifnum=2, 
                          colors='classic', axes_type='rails', vsep=.02, width=.9, ytick_format='%.1f')

# %%
logo= logomaker.make_logo(iupac_string='GYCATRKMNV', colors='classic', axes_type='rails', vsep=.05, width=.9)
