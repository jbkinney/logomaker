# %%
from __future__ import division
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl
import re

# Import LogoMaker
import sys
sys.path.append('../')
import logomaker

# %matplotlib inline
plt.ion()

# %%
logomaker.get_fontnames()
# Out:
# [u'.Keyboard',
#  u'.LastResort',
#  u'.SF Compact Display',
#  u'.SF Compact Rounded',
#  u'.SF Compact Text',
#  u'.SF NS Display Condensed',
#  u'.SF NS Text Condensed',
#  u'Adobe Arabic',
#  u'Adobe Caslon Pro',
#  u'Adobe Devanagari',
#  u'Adobe Fan Heiti Std',
#  u'Adobe Fangsong Std',
#  u'Adobe Garamond Pro',
#  u'Adobe Gothic Std',
#  u'Adobe Hebrew',
#  u'Adobe Heiti Std',
#  u'Adobe Kaiti Std',
#  u'Adobe Ming Std',
#  u'Adobe Myungjo Std',
#  u'Adobe Naskh',
#  u'Adobe Song Std',
#  u'Andale Mono',
#  u'Apple Braille',
#  u'Apple Chancery',
#  u'Apple Symbols',
#  u'AppleGothic',
#  u'AppleMyungjo',
#  u'Arial',
#  u'Arial Black',
#  u'Arial Narrow',
#  u'Arial Rounded MT Bold',
#  u'Arial Unicode MS',
#  u'Ayuthaya',
#  u'Batang',
#  u'Big Caslon',
#  u'Birch Std',
#  u'Bitstream Vera Sans',
#  u'Bitstream Vera Sans Mono',
#  u'Bitstream Vera Serif',
#  u'Blackoak Std',
#  u'Bodoni 72 Smallcaps',
#  u'Bodoni Ornaments',
#  u'Bookshelf Symbol 7',
#  u'Bradley Hand',
# ...

# %%
# Have to implement the reading of matrices from csv files. Hm, this is going to take some work.
logomaker.make_logo(matrix_csvfile='data/DBF.logo.txt',
                    csv_delim_whitespace=True,
                    csv_index_col='Position',
                    figsize=[10,6],
                    character_colors='random',
                    font_family='Stencil Std',
                    vsep=.01)
# Out:
# <logomaker.Logo.Logo instance at 0x122896ef0>

# %%
# Have to implement the reading of matrices from csv files. Hm, this is going to take some work.
logo= logomaker.make_logo(matrix_csvfile='data/DBF.logo.txt',
                          csv_delim_whitespace=True,
                          csv_index_col='Position',
                          ylim=[-.5,.4], 
                          yticks=[-.5,0,.4],
                          yticklabels=['-0.5','0','+0.4'],
                          xlim=[-7,6],
                          shift_first_position_to=-6, 
                          show_position_zero=False,
                          bottom_spine=False,
                          baseline_style=':',
                          baseline_width=1.5,
                          xlabel='Alpha helix poxition',
                          ylabel='Contribution to DBF model',
                          figsize=[3.5,2.5],
                          font_family='Arial',
                          font_weight='heavy',
                          max_stretched_character='M',
                          fullheight_boxcolors=[.96, .95, .60],
                          fullheight_zorder=-10,
                          width=.8,
                          vsep=.02,
                          fullheight_vsep=0,
                          fullheight_width=1,
                          character_colors={'DEC': [.42, .16, .42],
                                            'PG': [.47, .47, 0.0],
                                            'MIWALFV': [.13, .35, .61],
                                            'NTSQ': [.25, .73, .28],
                                            'RK': [.74, .18, .12],
                                            'HY': [.09, .47, .46]},
                          fullheight=[-1,1,2,5],
                          below_alpha=.5, 
                          remove_flattened_characters=True,
                          xtick_format='%+d',
                          use_tightlayout=True,
                          axes_fontsize=11,
                          save_to_file='NajafabadiEtAl2017.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d437363f172e> in <module>()
#       1 # Have to implement the reading of matrices from csv files. Hm, this is going to take some work.
# ----> 2 logo= logomaker.make_logo(matrix_csvfile='data/DBF.logo.txt',
#       3                           csv_delim_whitespace=True,
#       4                           csv_index_col='Position',
#       5                           ylim=[-.5,.4],
#
# NameError: name 'logomaker' is not defined

# %%
pd.read_csv?
