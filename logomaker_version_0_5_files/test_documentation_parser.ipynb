# %%
from __future__ import division
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl

import re

# Import LogoMaker
import sys

# %matplotlib inline
plt.ion()

# %%
sys.path.append('..')
import logomaker

# %%
from logomaker.documentation_parser import parse_documentation_file
doc_dict = parse_documentation_file('make_logo_arguments.txt')

# %%
for key, val in doc_dict.items():
    print key, ':',  val.num_in_section, val.section
# Out:
# background_mattype : 21 Matrix transformation
# character_boxedgecolors : 7 Logo character styling
# xlim : 0 x-axis formatting
# baseline_style : 4 Baseline formatting
# axes_fontfamily : 1 Default axes font
# matrix_type : 22 Matrix transformation
# highlight_boxedgealpha : 10 Highlighted logo character styling
# baseline_width : 1 Baseline formatting
# character_colors : 0 Logo character styling
# below_flip : 5 Character placement
# scalebar_length : 1 Scalebar formatting
# background_ctcol : 18 Matrix transformation
# show_position_zero : 2 Position choice
# fullheight_edgecolors : 3 Fixed character styling
# ylabel : 7 y-axis formatting
# vline_width : 1 vlines formatting
# character_boxcolors : 5 Logo character styling
# position_range : 0 Position choice
# below_shade : 3 Character placement
# axes_type : 0 Axes formatting
# tick_fontfamily : 1 Tick label font
# vline_color : 2 vlines formatting
# font_weight : 3 Logo character font
# show_baseline : 0 Baseline formatting
# xticklabels : 4 x-axis formatting
# background : 24 Matrix transformation
# xtick_spacing : 2 x-axis formatting
# xtick_length : 6 x-axis formatting
# draw_now : 1 Immediate drawing
# ignore_characters : 2 Position choice
# use_tightlayout : 5 Other axes formatting
# tick_fontweight : 2 Tick label font
# title_fontstyle : 3 Title font
# fullheight_width : 13 Fixed character styling
# logo_type : 23 Matrix transformation
# counts_threshold : 29 Matrix transformation
# dpi : 3 Immediate drawing
# baseline_zorder : 5 Baseline formatting
# use_transparency : 1 Character placement
# character_boxalpha : 6 Logo character styling
# scalebar_textrotation : 9 Scalebar formatting
# highlight_zorder : 12 Highlighted logo character styling
# csv_delimiter : 12 Matrix transformation
# background_seqcsvfile : 16 Matrix transformation
# meme_motifnum : 4 Matrix transformation
# sequences_csvfile : 6 Matrix transformation
# matrix : 0 Matrix transformation
# scalebar_ymin : 6 Scalebar formatting
# fullheight_boxedgecolors : 8 Fixed character styling
# ytick_format : 6 y-axis formatting
# center_columns : 27 Matrix transformation
# sequence_type : 0 Position choice
# ct_col : 8 Matrix transformation
# uniform_stretch : 10 Character placement
# highlight_edgewidth : 6 Highlighted logo character styling
# fullheight_colors : 1 Fixed character styling
# font_properties : 0 Logo character font
# csv_index_col : 10 Matrix transformation
# information_units : 28 Matrix transformation
# baseline_alpha : 3 Baseline formatting
# font_family : 2 Logo character font
# highlight_sequence : 0 Highlighted logo character styling
# scalebar_texthalignment : 7 Scalebar formatting
# character_boxedgealpha : 8 Logo character styling
# highlight_edgealpha : 5 Highlighted logo character styling
# tick_fontfile : 0 Tick label font
# character_edgecolors : 2 Logo character styling
# stack_order : 0 Character placement
# xtick_anchor : 3 x-axis formatting
# fullheight_edgealpha : 4 Fixed character styling
# meme_motifname : 3 Matrix transformation
# yticklabels : 3 y-axis formatting
# show_gridlines : 0 Gridline formatting
# highlight_bgconsensus : 1 Highlighted logo character styling
# seq_col : 7 Matrix transformation
# show_binary_yaxis : 0 y-axis formatting
# vline_zorder : 5 vlines formatting
# title_fontfamily : 1 Title font
# fullheight_alpha : 2 Fixed character styling
# fullheight_boxalpha : 7 Fixed character styling
# csv_header : 13 Matrix transformation
# meme_file : 2 Matrix transformation
# axes_fontstyle : 3 Default axes font
# character_edgewidth : 4 Logo character styling
# style_sheet : 1 Axes formatting
# font_file : 1 Logo character font
# hpad : 6 Character placement
# tick_fontsize : 4 Tick label font
# axes_fontweight : 2 Default axes font
# matrix_csvfile : 9 Matrix transformation
# pseudocount : 25 Matrix transformation
# title_fontsize : 4 Title font
# highlight_boxcolors : 7 Highlighted logo character styling
# csv_usecols : 14 Matrix transformation
# background_csvkwargs : 19 Matrix transformation
# character_boxedgewidth : 9 Logo character styling
# label_fontweight : 2 Axis label font
# fullheight_boxedgealpha : 9 Fixed character styling
# ytick_length : 5 y-axis formatting
# fullheight_boxcolors : 6 Fixed character styling
# xticks : 1 x-axis formatting
# width : 8 Character placement
# gridline_alpha : 4 Gridline formatting
# vsep : 9 Character placement
# vline_alpha : 3 vlines formatting
# character_edgealpha : 3 Logo character styling
# axes_fontfile : 0 Default axes font
# title_fontfile : 0 Title font
# highlight_colors : 2 Highlighted logo character styling
# tick_fontstyle : 3 Tick label font
# axes_fontsize : 4 Default axes font
# background_matcsvfile : 20 Matrix transformation
# max_positions_per_line : 4 Immediate drawing
# fullheight_zorder : 11 Fixed character styling
# scalebar_text : 4 Scalebar formatting
# highlight_alpha : 3 Highlighted logo character styling
# scalebar_textvalignment : 8 Scalebar formatting
# scalebar_x : 5 Scalebar formatting
# highlight_edgecolors : 4 Highlighted logo character styling
# fullheight_vsep : 12 Fixed character styling
# highlight_boxedgewidth : 11 Highlighted logo character styling
# gridline_axis : 1 Gridline formatting
# xlabel : 8 x-axis formatting
# label_fontfamily : 1 Axis label font
# left_spine : 1 Other axes formatting
# iupac_string : 5 Matrix transformation
# character_alpha : 1 Logo character styling
# highlight_boxedgecolors : 9 Highlighted logo character styling
# fasta_file : 1 Matrix transformation
# rcparams : 2 Axes formatting
# gridline_style : 5 Gridline formatting
# remove_flattened_characters : 12 Character placement
# character_zorder : 10 Logo character styling
# xtick_format : 7 x-axis formatting
# gridline_color : 3 Gridline formatting
# baseline_color : 2 Baseline formatting
# enrichment_logbase : 26 Matrix transformation
# label_fontfile : 0 Axis label font
# ylim : 1 y-axis formatting
# show_scalebar : 0 Scalebar formatting
# font_style : 4 Logo character font
# vpad : 7 Character placement
# max_alpha_val : 2 Character placement
# xtick_rotation : 5 x-axis formatting
# below_alpha : 4 Character placement
# shift_first_position_to : 1 Position choice
# csv_kwargs : 15 Matrix transformation
# figsize : 0 Immediate drawing
# top_spine : 3 Other axes formatting
# highlight_boxalpha : 8 Highlighted logo character styling
# max_stretched_character : 11 Character placement
# fullheight_boxedgewidth : 10 Fixed character styling
# yticks : 2 y-axis formatting
# ytick_rotation : 4 y-axis formatting
# label_fontsize : 4 Axis label font
# vline_style : 4 vlines formatting
# gridline_width : 2 Gridline formatting
# characters : 1 Position choice
# scalebar_color : 3 Scalebar formatting
# csv_delim_whitespace : 11 Matrix transformation
# label_fontstyle : 3 Axis label font
# bottom_spine : 4 Other axes formatting
# title_fontweight : 2 Title font
# save_to_file : 2 Immediate drawing
# scalebar_linewidth : 2 Scalebar formatting
# background_seqcol : 17 Matrix transformation
# fullheight : 0 Fixed character styling
# vline_positions : 0 vlines formatting
# right_spine : 2 Other axes formatting
# title : 0 Other axes formatting
# negate_matrix : 30 Matrix transformation
# fullheight_edgewidth : 5 Fixed character styling

# %%
logomaker.make_logo?
