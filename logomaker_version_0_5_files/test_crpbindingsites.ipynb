# %%
from __future__ import division
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl

# Import LogoMaker
import sys
sys.path.append('../')
import logomaker

# %matplotlib inline
plt.ion()

# %%
logo = logomaker.make_logo(fasta_file='data/crp_sites.fasta', 
                           logo_type='enrichment',
                           axes_type='scalebar',
                           show_scalebar=True,
                           xtick_spacing=1,
                           draw_now=True)

# %%
param_dict = logomaker.documentation_parser.parse_documentation_file('make_logo_arguments.txt')

# %%
param_pairs = [(val.param_num, val.section, val.name) for val in param_dict.values()]
for num, section, name in sorted(param_pairs):
    print '%d: %s, %s '%(num, section, name)
# Out:
# 1: Matrix transformation, matrix
# 2: Matrix transformation, fasta_file
# 3: Matrix transformation, meme_file
# 4: Matrix transformation, meme_motifname
# 5: Matrix transformation, meme_motifnum
# 6: Matrix transformation, iupac_string
# 7: Matrix transformation, sequences_csvfile
# 8: Matrix transformation, seq_col
# 9: Matrix transformation, ct_col
# 10: Matrix transformation, matrix_csvfile
# 11: Matrix transformation, csv_index_col
# 12: Matrix transformation, csv_delim_whitespace
# 13: Matrix transformation, csv_delimiter
# 14: Matrix transformation, csv_header
# 15: Matrix transformation, csv_usecols
# 16: Matrix transformation, csv_kwargs
# 17: Matrix transformation, background_seqcsvfile
# 18: Matrix transformation, background_seqcol
# 19: Matrix transformation, background_ctcol
# 20: Matrix transformation, background_csvkwargs
# 21: Matrix transformation, background_matcsvfile
# 22: Matrix transformation, background_mattype
# 23: Matrix transformation, matrix_type
# ...
