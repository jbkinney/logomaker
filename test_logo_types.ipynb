# %%
from __future__ import division
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd

# Import LogoMaker
import logomaker

# %matplotlib inline
plt.ion()

# %%
# Load counts matrix from fasta file
counts_mat = logomaker.load_alignment(file_name='crp_sites.fasta')

# %%
# Make all logo types
wtseq = 'ATTAATGTGAGTTAGCTCACTCATTA'

parameters_txt = """
logo_type : 'enrichment'
colors : 'random'
hpad : .5
vpad : 0.1
below_flip : False
foo : 'bar'
"""
with open('parameters.txt','w') as f:
    f.write(parameters_txt)

probability_logo = logomaker.make_logo(counts_mat, 'parameters.txt',  
                                      font_family = 'fantasy', )
fig, ax = plt.subplots(figsize=[8,2])
probability_logo.draw(ax)

fig.tight_layout()
# Out:
# ### Parameters ###
# [file] below_flip : False
# [file] colors : 'random'
# [file] hpad : 0.5
# [file] logo_type : 'enrichment'
# [file] vpad : 0.1
# [user] font_family : 'fantasy'

# %%
import inspect

# %%
inspect.getargspec(logomaker.make_logo)
# Out:
# ArgSpec(args=[], varargs='args', keywords='kwargs', defaults=None)
