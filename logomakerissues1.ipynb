# %% [markdown]
# Most recent pull, by default 'None' appears as Y axis label

# %%
from __future__ import division
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd

# Import LogoMaker
import logomaker

# %matplotlib inline
plt.ion()

# %%
counts_mat = logomaker.load_alignment('crp_sites.fasta')

# %%
counts_mat.logomaker_type
# Out:
# 'counts'

# %%
plt.clf()
fig,ax = plt.subplots()
logo = logomaker.make_logo(mat=counts_mat)
logo.draw(ax)
plt.show()

# %%
logo.logo_type
# Out:
# 'generic'

# %% [markdown]
# Previous Pull.

# %%
fig,ax = plt.subplots()
logo = logomaker.Logo(mat=counts_mat,baseline_width=1)
logo.draw(ax)
plt.show()
