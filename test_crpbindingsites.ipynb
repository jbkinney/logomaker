# %%
from __future__ import division
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd

# Import LogoMaker
import logomaker

# %matplotlib inline
plt.ion()

# %%
# Load CRP sequences used by WebLogo
matrix = logomaker.load_alignment(fasta_file='data/weblogo/cap.fa',sequence_type='DNA')

# %%
# Make logo
logomaker.make_styled_logo(matrix=matrix,
                           highlight_sequence='TAATGTGAGTTAGCTCACTCAT'.lower(),
                           logo_type='probability',
                           colors='tomato',
                           highlight_colors='black',
                           axes_type='rails',
                           sequence_type='dna',
                           font_family='fantasy',
                           figsize=[10,2],
                           #position_range=[2,20],
                           #shift_first_position_to=-10,
                           width=.8,
                           vpad=.1,
                           rcparams={'font.size':12});
#logomaker.make_logo(matrix=matrix, logo_type='enrichment', colors='classic', figsize=[10,2], axes_type='rails')
