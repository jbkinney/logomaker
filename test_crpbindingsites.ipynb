# %%
from __future__ import division
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl

# Import LogoMaker
import logomaker

# %matplotlib inline
plt.ion()

# %%
# Load CRP sequences used by WebLogo
matrix = logomaker.load_alignment(fasta_file='data/weblogo/cap.fa',sequence_type='DNA')

# %%
logomaker.make_logo(matrix=matrix, figsize=[10,2], colors='classic')
# Out:
# <Logo.Logo instance at 0x10fd20b00>

# %%
parameters_content = """
show_gridlines=True,
colors='classic',
balls='hi there', 
show_gridlines=False,
font_name='Arial Rounded MT Bold',
"""
with open('parameters.txt','w') as f:
    f.write(parameters_content)

logomaker.make_styled_logo(style_file='parameters.txt', matrix=matrix, figsize=[10,2])
# Out:
# [set] show_gridlines = True
# [set] colors = 'classic'
# [set] balls = 'hi there'
# [set] show_gridlines = False
# [set] font_name = 'Arial Rounded MT Bold'
# Warning: Parameter 'balls' is invalid. Ignoring it.
# <Logo.Logo instance at 0x1104cd5a8>

# %%
parameters_content = """
show_gridlines=True,
gridline_axis='x',
gridline_color='gray',
gridline_style=':',
stack_order='small_on_top',
use_transparency=True,
xtick_spacing=5,
xtick_anchor=0,
xtick_length=0,
boxalpha=0,
width=.9,
vpad=.1,
axes_type='naked',
logo_type='probability',
title_fontsize=12,
tick_fontsize=8,
font_name='Luminari',
#font_family='Arial Rounded MT Bold',
axes_fontname='Luminari',
title='CRP binding sites',
colors='classic',
show_baseline=False
"""
with open('parameters.txt','w') as f:
    f.write(parameters_content)

logomaker.make_styled_logo(style_file='parameters.txt', matrix=matrix, figsize=[10,2])
# Out:
# [set] show_gridlines = True
# [set] gridline_axis = 'x'
# [set] gridline_color = 'gray'
# [set] gridline_style = ':'
# [set] stack_order = 'small_on_top'
# [set] use_transparency = True
# [set] xtick_spacing = 5
# [set] xtick_anchor = 0
# [set] xtick_length = 0
# [set] boxalpha = 0
# [set] width = .9
# [set] vpad = .1
# [set] axes_type = 'naked'
# [set] logo_type = 'probability'
# [set] title_fontsize = 12
# [set] tick_fontsize = 8
# [set] font_name = 'Luminari'
# [set] axes_fontname = 'Luminari'
# [set] title = 'CRP binding sites'
# [set] colors = 'classic'
# Warning: could not parse line "show_baseline=False".
# <Logo.Logo instance at 0x112ec9050>

# %%
logomaker.get_fontnames()
# Out:
# [u'.Keyboard',
#  u'.LastResort',
#  u'.SF Compact Display',
#  u'.SF Compact Rounded',
#  u'.SF Compact Text',
#  u'.SF NS Display Condensed',
#  u'.SF NS Text Condensed',
#  u'Adobe Arabic',
#  u'Adobe Caslon Pro',
#  u'Adobe Devanagari',
#  u'Adobe Fan Heiti Std',
#  u'Adobe Fangsong Std',
#  u'Adobe Garamond Pro',
#  u'Adobe Gothic Std',
#  u'Adobe Hebrew',
#  u'Adobe Heiti Std',
#  u'Adobe Kaiti Std',
#  u'Adobe Ming Std',
#  u'Adobe Myungjo Std',
#  u'Adobe Naskh',
#  u'Adobe Song Std',
#  u'Andale Mono',
#  u'Apple Braille',
#  u'Apple Chancery',
#  u'Apple Symbols',
#  u'AppleGothic',
#  u'AppleMyungjo',
#  u'Arial',
#  u'Arial Black',
#  u'Arial Narrow',
#  u'Arial Rounded MT Bold',
#  u'Arial Unicode MS',
#  u'Ayuthaya',
#  u'Batang',
#  u'Big Caslon',
#  u'Birch Std',
#  u'Bitstream Charter',
#  u'Bitstream Vera Sans',
#  u'Bitstream Vera Sans Mono',
#  u'Bitstream Vera Serif',
#  u'Blackoak Std',
#  u'Bodoni 72 Smallcaps',
#  u'Bodoni Ornaments',
#  u'Bookshelf Symbol 7',
#  u'Bradley Hand',
#  u'Brush Script MT',
#  u'Brush Script Std',
#  u'Calibri',
#  u'Cambria',
#  u'Cambria Math',
#  u'Candara',
#  u'Century Schoolbook L',
#  u'Chalkduster',
#  u'Chaparral Pro',
#  u'Charlemagne Std',
#  u'Comic Sans MS',
#  u'Computer Modern',
#  u'Consolas',
#  u'Constantia',
#  u'Cooper Std',
#  u'Corbel',
#  u'Courier',
#  u'Courier 10 Pitch',
#  u'Courier New',
#  u'DIN Alternate',
#  u'DIN Condensed',
#  u'DejaVu Sans',
#  u'DejaVu Sans Display',
#  u'DejaVu Sans Mono',
#  u'DejaVu Serif',
#  u'DejaVu Serif Display',
#  u'Dingbats',
#  u'Diwan Thuluth',
#  u'East Syriac Adiabene',
#  u'East Syriac Ctesiphon',
#  u'Estrangelo Antioch',
#  u'Estrangelo Edessa',
#  u'Estrangelo Midyat',
#  u'Estrangelo Nisibin',
#  u'Estrangelo Nisibin Outline',
#  u'Estrangelo Quenneshrin',
#  u'Estrangelo Talada',
#  u'Estrangelo TurAbdin',
#  u'Farisi',
#  u'Franklin Gothic Book',
#  u'Franklin Gothic Medium',
#  u'Gabriola',
#  u'Georgia',
#  u'Giddyup Std',
#  u'Gill Sans MT',
#  u'Goha-Tibeb Zemen',
#  u'Gulim',
#  u'Gurmukhi MT',
#  u'Helvetica',
#  u'Herculanum',
#  u'Hobo Std',
#  u'Hoefler Text',
#  u'Humor Sans',
#  u'ITC Avant Garde Gothic',
#  u'ITC Bookman',
#  u'ITC Zapf Chancery',
#  u'ITC Zapf Dingbats',
#  u'Impact',
#  u'InaiMathi',
#  u'Khmer Sangam MN',
#  u'Kokonor',
#  u'Kozuka Gothic Pr6N',
#  u'Kozuka Gothic Pro',
#  u'Kozuka Mincho Pr6N',
#  u'Kozuka Mincho Pro',
#  u'Krungthep',
#  u'Lao Sangam MN',
#  u'Letter Gothic Std',
#  u'Lithos Pro',
#  u'Lucida Console',
#  u'Lucida Sans Unicode',
#  u'Luminari',
#  u'Luxi Mono',
#  u'Luxi Sans',
#  u'Luxi Serif',
#  u'MS Gothic',
#  u'MS Mincho',
#  u'MS PGothic',
#  u'MS PMincho',
#  u'MS Reference Sans Serif',
#  u'MS Reference Specialty',
#  u'Marlett',
#  u'Meiryo',
#  u'Mesquite Std',
#  u'Microsoft Himalaya',
#  u'Microsoft Sans Serif',
#  u'Microsoft Tai Le',
#  u'Microsoft Yi Baiti',
#  u'MingLiU',
#  u'MingLiU-ExtB',
#  u'MingLiU_HKSCS',
#  u'MingLiU_HKSCS-ExtB',
#  u'Minion Pro',
#  u'Mishafi',
#  u'Mishafi Gold',
#  u'Mongolian Baiti',
#  u'Myriad Arabic',
#  u'Myriad Hebrew',
#  u'Myriad Pro',
#  u'New Century Schoolbook',
#  u'Nimbus Mono L',
#  u'Nimbus Roman No9 L',
#  u'Nimbus Sans L',
#  u'Nueva Std',
#  u'OCR A Std',
#  u'Orator Std',
#  u'PMingLiU',
#  u'PMingLiU-ExtB',
#  u'Palatino',
#  u'Palatino Linotype',
#  u'Perpetua',
#  u'Plantagenet Cherokee',
#  u'Poplar Std',
#  u'Prestige Elite Std',
#  u'Rosewood Std',
#  u'STIXGeneral',
#  u'STIXIntegralsD',
#  u'STIXIntegralsSm',
#  u'STIXIntegralsUp',
#  u'STIXIntegralsUpD',
#  u'STIXIntegralsUpSm',
#  u'STIXNonUnicode',
#  u'STIXSizeFiveSym',
#  u'STIXSizeFourSym',
#  u'STIXSizeOneSym',
#  u'STIXSizeThreeSym',
#  u'STIXSizeTwoSym',
#  u'STIXVariants',
#  u'Sathu',
#  u'Serto Batnan',
#  u'Serto Jerusalem',
#  u'Serto Jerusalem Outline',
#  u'Serto Kharput',
#  u'Serto Malankara',
#  u'Serto Mardin',
#  u'Serto Urhoy',
#  u'Silom',
#  u'SimHei',
#  u'SimSun',
#  u'SimSun-ExtB',
#  u'Skia',
#  u'Standard Symbols L',
#  u'Stencil Std',
#  u'Symbol',
#  u'System Font',
#  u'Tahoma',
#  u'Tekton Pro',
#  u'Times',
#  u'Times New Roman',
#  u'Trajan Pro',
#  u'Trattatello',
#  u'Trebuchet MS',
#  u'Tw Cen MT',
#  u'URW Antiqua T',
#  u'URW Bookman L',
#  u'URW Chancery L',
#  u'URW Gothic L',
#  u'URW Grotesk T',
#  u'URW Palladio L',
#  u'Utopia',
#  u'Verdana',
#  u'Webdings',
#  u'Wingdings',
#  u'Wingdings 2',
#  u'Wingdings 3',
#  u'Zapf Dingbats',
#  u'ZapfDingbats',
#  u'Zapfino',
#  u'cmb10',
#  u'cmex10',
#  u'cmmi10',
#  u'cmr10',
#  u'cmss10',
#  u'cmsy10',
#  u'cmtt10']

# %%
# Make logo
logomaker.make_styled_logo(matrix=matrix,
                           highlight_sequence='TAATGTGAGTTAGCTCACTCAT',
                           logo_type='probability',
                           colors='tomato',
                           highlight_colors='green',
                           axes_type='classic',
                           title_fontsize=16,
                           title='CRP binding sites in E. coli',
                           sequence_type='DNA',
                           font_name='Impact',
                           shift_first_position_to=-10,
                           xtick_rotation=0,
                           xtick_length=2,
                           xtick_spacing=5,
                           yticks=[0,.5,1],
                           figsize=[10,2],
                           show_gridlines=False,
                           gridline_axis='x',
                           gridline_color='y',
                           width=.8,
                           vpad=.1)
# Out:
# <Logo.Logo instance at 0x111b683f8>

# %%
np.e
# Out:
# 2.718281828459045
