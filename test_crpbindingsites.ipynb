# %%
from __future__ import division
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl

# Import LogoMaker
import sys
sys.path.append('../')
import logomaker

# %matplotlib inline
plt.ion()

# %%
logo = logomaker.make_logo(fasta_file='data/crp_sites.fasta', 
                           logo_type='enrichment',
                           axes_type='scalebar',
                           show_scalebar=True,
                           xtick_spacing=1,
                           scalebar_length=1,
                           scalebar_text='2x',
                           scalebar_ymin=-4,
                           scalebar_color='tomato',
                           draw_now=True)
