# %%
from __future__ import division
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl

# Import LogoMaker
import logomaker

# %matplotlib inline
plt.ion()

# %%
logo = logomaker.make_logo(fasta_file='data/crp_sites.fasta', 
                           logo_type='enrichment',
                           axes_type='scalebar',
                           scalebar_ymin=-4,
                           scalebar_length=2,
                           scalebar_text='2 units')

# %%
logo = logomaker.make_logo(fasta_file='data/crp_sites.fasta', 
                           logo_type='enrichment',
                           show_scalebar=True,
                           scalebar_x=25,
                           scalebar_length=2,
                           scalebar_ymin=-4,
                           scalebar_text='4x',
                           yticks=[],
                           left_spine=False)

# %%
fig, ax = plt.subplots(figsize=[10,2])
logo.draw(ax)
# ax.annotate("",xy=(-2,-4),xytext=(-2,-2), xycoords='data', textcoords='data', 
#             arrowprops=dict(arrowstyle="-",connectionstyle="arc3"))
# plt.show()
line = mpl.lines.Line2D(xdata=[.5,.5], ydata=[-2,-4], color='black', linewidth=2)
text = mpl.text.Text(text='4-fold', x=.5, y=-3, verticalalignment='center', horizontalalignment='right', rotation=90)
ax.add_artist(line)
ax.add_artist(text)

# %%
ax.add_line?
