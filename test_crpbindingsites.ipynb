# %%
from __future__ import division
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl

# Import LogoMaker
import logomaker

# %matplotlib inline
plt.ion()

# %%
logo = logomaker.make_logo(fasta_file='data/crp_sites.fasta', 
                           logo_type='enrichment', 
                           shift_first_position_to=-13, 
                           show_position_zero=False, 
                           fullheight=range(5,10), 
                           fullheight_boxcolors='cyan',
                           fullheight_boxalpha=1,
                           character_colors='classic',
                           fullheight_zorder=-30,
                           character_zorder=0, 
                           baseline_width=10, 
                           baseline_zorder=-5,
                           axes_type='everything',
                           xlabel='',
                           #vsep=.05,
                           #fullheight_vsep=0.0,
                           width=.9,
                           fullheight_width=1.0,
                           #stack_order='fixed_going_down',
                           vpad=0,
                           hpad=0)

# %%
print logomaker.load_meme('data/ZNF64_meme_motif.txt', get_filecontents=True)
# Out:
# MEME version 4.11.2
#
# ALPHABET= ACGT
#
# strands: + -
#
# Background letter frequencies (from unknown source):
# A 0.183 C 0.317 G 0.317 T 0.183
#
# MOTIF 1
#
# log-odds matrix: alength= 4 w= 20 E= 1.3e-186
#    -25    -23     58    -82
#    -61    -19     79   -178
#     41    -54     50   -102
#      9   -160     90    -75
#   -225    128   -134   -149
#   -319    147   -218   -269
#   -219    140   -277   -122
#    -38    -43     79   -125
#   -238  -1587    159   -419
#   -197   -271    149   -345
#    155   -100    -30   -197
#    121     22    -74   -345
#    -78     20    -93     99
#    -71     94    -55   -149
#     62   -187    -22     98
#   -397   -131    139   -278
#   -128     67    -60     21
#    110    -80     -6    -59
#   -145    -30    -32    120
#    -16    -32      2     52
#
#
# letter-probability matrix: alength= 4 w= 20 nsites= 600 E= 1.3e-186
# 0.153333 0.270000 0.473333 0.103333
# 0.120000 0.278333 0.548333 0.053333
# 0.243333 0.218333 0.448333 0.090000
# ...

# %%
np.ndarray
# Out:
# numpy.ndarray
