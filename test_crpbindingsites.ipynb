# %%
from __future__ import division
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl

# Import LogoMaker
import logomaker

# %matplotlib inline
plt.ion()

# %%
# Load CRP sequences used by WebLogo
matrix = logomaker.load_alignment(fasta_file='data/weblogo/cap.fa',sequence_type='DNA')

# %%
logomaker.make_logo(matrix=matrix, figsize=[10,2], colors='classic')
# Out:
# <Logo.Logo instance at 0x10f7c1518>

# %%
logomaker.make_logo(matrix=matrix,
                    show_gridlines=True,
                    gridline_axis='x',
                    gridline_color='gray',
                    gridline_style=':',
                    stack_order='small_on_top',
                    use_transparency=True,
                    xtick_spacing=5,
                    xtick_anchor=1,
                    xtick_length=0,
                    figsize=[10,2], 
                    boxalpha=0,
                    width=.9,
                    vpad=.1,
                    axes_type='naked',
                    logo_type='probability',
                    title_fontsize=12,
                    tick_fontsize=8,
                    font_family='Arial Rounded MT Bold',
                    title='CRP binding sites',
                    colors='classic',
                    show_baseline=False)
# Out:
# <Logo.Logo instance at 0x10f7ac128>

# %%
# Make logo
logomaker.make_styled_logo(matrix=matrix,
                           highlight_sequence='TAATGTGAGTTAGCTCACTCAT',
                           logo_type='probability',
                           colors='tomato',
                           highlight_colors='green',
                           axes_type='classic',
                           title_fontsize=16,
                           title='CRP binding sites in E. coli',
                           sequence_type='DNA',
                           font_name='Impact',
                           shift_first_position_to=-10,
                           xtick_rotation=0,
                           xtick_length=2,
                           xtick_spacing=5,
                           yticks=[0,.5,1],
                           figsize=[10,2],
                           show_gridlines=False,
                           gridline_axis='x',
                           gridline_color='y',
                           width=.8,
                           vpad=.1)
# Out:
# <Logo.Logo instance at 0x10f7f2518>

# %%
plt.style.use('dark_background')
logomaker.make_logo(matrix=matrix, logo_type='enrichment', 
                    figsize=[10,2], colors='classic', baseline_style='--')
# Out:
# <Logo.Logo instance at 0x112079560>

# %%
np.e
# Out:
# 2.718281828459045
