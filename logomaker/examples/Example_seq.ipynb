# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
% matplotlib inline
plt.ion()

import sys
sys.path.append('/Users/jkinney/github/logomaker_dev/')
import logomaker

# %%
df = logomaker.sequence_to_matrix('ACGNNN', is_iupac=True)
logo = logomaker.Logo(df)

# %%
df = logomaker.sequence_to_matrix('ACACGT', alphabet='dna')
logo = logomaker.Logo(df)
