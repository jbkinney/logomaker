# %%
import sys
sys.path.append('../../')

# %%
import logomaker
# %matplotlib inline

# import dataframe
df = -logomaker.get_example_matrix('crp_energy_matrix', 
                                   print_description=False)

# %%
# the 'colorblind_safe' color scheme will be included 
# in next realease of Logomaker
logomaker.Logo(df, color_scheme='colorblind_safe')

# %%
# for now, do this:

# define color scheme
colorblind_safe = {
    'A': '#009980',
    'C': '#59B3E6',
    'G': '#E69B04',
    'TU': '#1A1A1A'
}

# make logo with specified color scheme
logomaker.Logo(df, color_scheme=colorblind_safe)
