# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
plt.ion()

import sys
sys.path.append('../../')

import logomaker

# %%
# Create a logo
df = pd.read_csv('../data/rnap_tau_final_all.41.matrix.txt', delim_whitespace=True)
df.head()
# Out:
#         A       C       G       T
# 0  0.0089  0.1109  0.0000  0.0963
# 1  0.0400  0.2615  0.0000  0.3227
# 2  0.0640  0.0240  0.0499  0.0000
# 3  0.0000  0.1247  0.0216  0.1117
# 4  0.5063  0.0463  0.0000  1.0121

# %%
logo = logomaker.Logo(df,color_scheme='salmon')

# %%
from logomaker import Glyph

fig, ax = plt.subplots(figsize=[8,3])
ax.set_xlim([-1,2])
ax.set_ylim([-1,1])
Glyph(c='Z', p=0,ax=ax,ceiling=1,floor=-1)
Glyph(c='G', p=1, width=.75, alpha=.5, font_name='Arial Rounded MT Bold',font_weight=0,ceiling=1,floor=-1, 
      color='dodgerblue', flip=False, mirror=True, edgecolor='red',edgewidth=1)

# %%
fig, ax = plt.subplots(figsize=[15,3])

# Style axes
s = 'LOGOMAKER'
ax.set_ylim([0,1])
ax.set_xlim([-.5,len(s)-.5])
#ax.axis('off')

# Create a list of glyphs
glyphs = []
for p, c in enumerate(s):
    g = Glyph(c=c, p=p,ax=ax, draw_now=False, ceiling=1,floor=0,color='black')
    glyphs.append(g)
    
# Modify a single glyph
g = glyphs[5]
g.color='dodgerblue'
g.floor=.5
g.font_name='Comic Sans MS'
g.flip=False

# Draw all glyphs
for g in glyphs:
    g.draw()
