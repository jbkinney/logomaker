# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
plt.ion()

import sys
sys.path.append('../../')
import logomaker

# %%
# Load data
mat_df = pd.read_excel('PVIVIT_matrix_ddG.xlsx', index_col=0).fillna(0)
mat_df
# Out:
#             A    C         D         E         F         G         H  \
# pos
# 0    0.153293  0.0  0.000000 -0.937050 -0.135357  0.023723  0.000000
# 1    0.000000  0.0  0.000000  0.000000 -1.839699  0.000000  0.000000
# 2    0.077770  0.0  0.000000  0.000000 -0.225309  0.000000  0.000000
# 3    0.000000  0.0  0.000000  0.000000 -0.505516  0.000000  0.000000
# 4    0.000000  0.0  0.000000  0.000000 -0.655686  0.000000  0.000000
# 5    0.000000  0.0 -2.570754 -2.608185  0.000000  0.000000 -2.174893
# 6    0.000000  0.0 -1.762241 -1.191295 -1.839699  0.000000 -0.557457
# 7    0.542955  0.0 -0.536796  0.294722  0.000000  0.000000  0.191139
# 8    0.170870  0.0 -1.028105 -0.770475 -0.820973  0.000000  0.000000
# 9    0.527628  0.0  0.465973  0.000000 -0.145113  0.795942  0.000000
#
#             I         K         L    ...            P         Q         R  \
# pos                                  ...
# 0    1.073310  0.000000  0.000000    ...     0.000000 -0.147930  0.174980
# 1   -1.642144  0.000000 -1.754228    ...     0.000000  0.000000 -0.583321
# 2    0.136661  0.000000  0.297517    ...     0.000000  0.069087  1.472849
# 3    0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 4   -0.479178 -0.171860 -0.141291    ...     0.000000 -0.892703  0.182021
# 5    0.000000 -1.708295 -0.579565    ...     0.000000 -2.633935 -1.950580
# 6    0.000000 -0.941178  0.000000    ...     0.000000 -1.081896 -0.545062
# 7    0.000000  0.666855  0.000000    ...     0.000000 -0.567499  0.000000
# 8   -0.584942  0.000000 -0.677337    ...     0.000000  0.000000 -0.399056
# 9    0.542995  0.000000  0.000000    ...     0.514597  0.795160  0.000000
#
#             S         T    U         V         Y         X         Z
# pos
# 0    0.000000  0.586912  0.0  1.020230  0.577918  0.000000  0.000000
# 1   -1.913002  0.000000  0.0  0.000000 -2.125999  0.000000  0.000000
# 2   -0.036077  0.139858  0.0  0.000000 -0.240808  0.000000  0.000000
# 3    0.000000  0.000000  0.0 -1.007373 -2.512232  0.000000  0.000000
# 4   -1.515115 -0.360522  0.0  0.000000 -0.192548  0.000000  0.000000
# 5   -2.577097  0.000000  0.0 -0.038936  0.000000  0.000000  0.000000
# 6   -0.727250  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 7    0.078221  0.038340  0.0  0.000000  0.000000  0.000000  0.000000
# 8   -0.507604 -0.790996  0.0 -0.068746 -0.618316  0.000000  0.000000
# 9    0.089680  0.522677  0.0  0.476972 -0.185825  2.078718  2.564189
#
# [10 rows x 22 columns]

# %%
# Create figure and axes objects
fig, ax = plt.subplots(figsize=[2.5,2.5])

# Draw logo
logo = logomaker.Logo(-mat_df, 
                      ax=ax,
                      color_scheme='gray',
                      center_values=True,  
                      flip_below=False, 
                      font_name='Arial Rounded MT Bold')

# Highlight glyphs in sequence
# WARNING! NEED TO GET UPDATED MEASUREMETNS FROM POLLY. 
# AND HIGHLIGHTED SEQUENCE SHOULD BE '..PVIVIT..' I THINK
logo.style_glyphs_in_sequence('.FNYSQD.DZ', color='salmon')

# # Turn all spines off expect the bottom spine
logo.style_spines(visible=False)
logo.style_spines(spines=['bottom'], visible=True)

# # Use left spine to create a scale bar
logo.style_spines(spines=['left'], visible=True, linewidth=3, bounds=[3,4])

# # Fade glyphs below x-axis
logo.style_glyphs_below(fade=.3)

# Do additional plot styling
L = len(mat_df)
ax.axhline(0,color='k',linewidth=.5, zorder=-1)
ax.set_xticks(range(L))
xticklabels = list(range(L))
xticklabels[0] = -1
ax.set_xticklabels(xticklabels)
ax.xaxis.set_tick_params(width=0)
ax.set_xlim([-1,L])
ax.set_yticks([])
ax.set_ylabel('$\Delta \Delta G$ (kcal/mol)')

# Tight layout
plt.tight_layout()

# Save as pdf
out_file = 'Example_Nguyen.pdf'
fig.savefig(out_file)
print('Done! Output written to %s.'%out_file)
# Out:
# Done! Output written to Example_Nguyen.pdf.
