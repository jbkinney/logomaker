# %%
from __future__ import division
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd

# Logo-generating module
import anylogo

# %matplotlib inline
plt.ion()

# %%
# Load energy matrix
energy_mat = pd.read_csv('crp_fullwt.26.txt',delim_whitespace=True)

mat = anylogo.data.validate_mat(energy_mat)
freq_mat = anylogo.data.transform_mat(energy_mat, from_type='energy_mat', to_type='freq_mat')
freq_mat.index.name='pos'

freq_mat.to_csv('crp_freq_mat.txt', sep='\t', float_format='%.2f')
freq_mat.head()
# Out:
#             A         C         G         T
# pos
# 0    0.402430  0.157201  0.142241  0.298128
# 1    0.489546  0.080117  0.174772  0.255566
# 2    0.413920  0.095172  0.131063  0.359845
# 3    0.364319  0.085459  0.058443  0.491779
# 4    0.302926  0.156568  0.215614  0.324891

# %%
fig = plt.figure(figsize=[3.3,3.5])

import matplotlib as mpl
mpl.rcParams['lines.linewidth'] = .5
mpl.rcParams['font.size'] = 5
mpl.rcParams['axes.labelsize'] = 8

# Plot information logo
ax = fig.add_subplot(3,1,1)
anylogo.Logo(mat=energy_mat, mat_type='energy_mat', 
             logo_type='info_logo', color_scheme='gist_rainbow').draw()
plt.title('information logo', fontsize=8)

# Plot frequency logo
ax = fig.add_subplot(3,1,2)
anylogo.Logo(mat=energy_mat, mat_type='energy_mat', font_name='Arial Bold',
             logo_type='freq_logo', color_scheme='black', logo_style='rails', 
             stack_order='small_on_top', use_transparency=True).draw()
plt.title('probability logo', fontsize=8)

# Plot energy logo
ax = fig.add_subplot(3,1,3)
anylogo.Logo(mat=energy_mat, mat_type='energy_mat', 
             logo_type='energy_logo', neg_flip=True, 
             logo_style='everything', font_name='Comic Sans MS Bold', color_scheme='classic').draw()
plt.title('energy logo', fontsize=8)

fig.tight_layout(h_pad=2)
fig.savefig('logos.pdf')

# %%
mpl.rcParams.keys()
# Out:
# [u'_internal.classic_mode',
#  u'agg.path.chunksize',
#  u'animation.avconv_args',
#  u'animation.avconv_path',
#  u'animation.bitrate',
#  u'animation.codec',
#  u'animation.convert_args',
#  u'animation.convert_path',
#  u'animation.ffmpeg_args',
#  u'animation.ffmpeg_path',
#  u'animation.frame_format',
#  u'animation.html',
#  u'animation.mencoder_args',
#  u'animation.mencoder_path',
#  u'animation.writer',
#  u'axes.autolimit_mode',
#  u'axes.axisbelow',
#  u'axes.edgecolor',
#  u'axes.facecolor',
#  u'axes.formatter.limits',
#  u'axes.formatter.offset_threshold',
#  u'axes.formatter.use_locale',
#  u'axes.formatter.use_mathtext',
#  u'axes.formatter.useoffset',
#  u'axes.grid',
#  u'axes.grid.axis',
#  u'axes.grid.which',
#  u'axes.hold',
#  u'axes.labelcolor',
#  u'axes.labelpad',
#  u'axes.labelsize',
#  u'axes.labelweight',
#  u'axes.linewidth',
#  u'axes.prop_cycle',
#  u'axes.spines.bottom',
#  u'axes.spines.left',
#  u'axes.spines.right',
#  u'axes.spines.top',
# ...
