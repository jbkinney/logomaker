# %%
from __future__ import division
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd

# Logo-generating module
import anylogo

# %matplotlib inline
plt.ion()

# %%
# Load energy model and tidy up
energy_df = pd.read_csv('crp.txt',delim_whitespace=True)
energy_df.head()
# Out:
#       A     C     G     T
# 0  0.00  0.94  1.04  0.30
# 1  0.00  1.81  1.03  0.65
# 2  0.00  1.47  1.15  0.14
# 3  0.30  1.75  2.13  0.00
# 4  0.07  0.73  0.41  0.00

# %%
fig = plt.figure(figsize=[8,2*num_types])

# Probability logo
ax = fig.add_subplot(3,1,1)
anylogo.draw(ax,energy_df=energy_df,logo_type='probability')

# Information logo
ax = fig.add_subplot(3,1,2)
anylogo.draw(ax,energy_df=energy_df,logo_type='information')

# Effect logo
ax = fig.add_subplot(3,1,3)
anylogo.draw(ax,energy_df=energy_df,logo_type='energy')

# Save logos
plt.tight_layout()
plt.savefig('logos.pdf')
